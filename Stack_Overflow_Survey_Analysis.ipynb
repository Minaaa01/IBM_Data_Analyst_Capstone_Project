# %% [markdown]
# # Introduction

# %% [markdown]
# *   **Dataset Description**: Stack Overflow, a popular website for developers, conducted an online survey of software professionals
# across the world. The survey data was later open sourced by Stack Overflow. The actual data set has around
# 90,000 responses.
#
#   In this project we will only 11552 responses and its 85 associated variables
#   1. Respondent: Randomized respondent ID number (not in order of survey response time)
#   2. **MainBranch**: Which of the following options best describes you today? Here, by “developer” we mean “someone who writes code.”
#   3. **Hobbyist**: Do you code as a hobby?
#   4. **OpenSourcer**: How often do you contribute to open source?
#   5. **OpenSource**: How do you feel about the quality of open source software (OSS)?
#   6. **Employment**: Which of the following best describes your current employment status?
#   7. **Country**: In which country do you currently reside?
#   8. Student: Are you currently enrolled in a formal, degree-granting college or university program?
#   9. **EdLevel**: Which of the following best describes the highest level of formal education that you’ve completed?
#   10. **UndergradMajor**: What was your main or most important field of study?
#   11. EduOther: Which of the following types of non-degree education have you used or participated in? Please select all that apply.
#   12. OrgSize: Approximately how many people are employed by the company or organization you work for?
#   13. **DevType**: Which of the following describe you? Please select all that apply.
#   14. YearsCode: Including any education, how many years have you been coding?
#   15. Age1stCode: At what age did you write your first line of code or program? (E.g., webpage,Hello World, Scratch project)
#   16. YearsCodePro: How many years have you coded professionally (as a part of your work)?
#   17. **CareerSat**: Overall, how satisfied are you with your career thus far?
#   18. **JobSat**: How satisfied are you with your current job? (If you work multiple jobs, answer for the one you spend the most hours on.)
#   19. MgrIdiot: How confident are you that your manager knows what they’re doing?
#   20. MgrMoney: Do you believe that you need to be a manager to make more money?
#   21. MgrWant: Do you want to become a manager yourself in the future?
#   22. JobSeek: Which of the following best describes your current job-seeking status?
#   23. LastHireDate:When was the last time that you took a job with a new employer?
#   24. **LastInt**: In your most recent successful job interview (resulting in a job offer), you were asked to… (check all that apply)
#   25. **FizzBuzz**: Have you ever been asked to solve FizzBuzz in an interview?
#   26. **JobFactors**: Imagine that you are deciding between two job offers with the same compensation, benefits, and location. Of the following factors, which 3 are MOST important to you?
#   27. ResumeUpdate: Think back to the last time you updated your resum鬠CV, or an online profile on a job site. What is the PRIMARY reason that you did so?
#   28. CurrencySymbol: Which currency do you use day-to-day? If your answer is complicated, please pick the one you’re most comfortable estimating in
#   29. CurrencyDesc: Which currency do you use day-to-day? If your answer is complicated, please pick the one you’re most comfortable estimating in.
#   30. CompTotal:What is your current total compensation (salary, bonuses, and perks, before taxes and deductions), in CurrencySymbol? Please enter a whole number in the box below, without any punctuation. If you are paid hourly, please estimate an equivalent weekly, monthly, or yearly salary. If you prefer not to answer, please leave the box empty
#   31. CompFreq: Is that compensation weekly, monthly, or yearly?
#   32. **ConvertedComp**: Salary converted to annual USD salaries using the exchange rate on 2019-02-01,assuming 12 working months and 50 working weeks.
#   33. **WorkWeekHrs**: On average, how many hours per week do you work?
#   34. **WorkPlan**: How structured or planned is your work?
#   35. **WorkChallenge**: Of these options, what are your greatest challenges to productivity as adeveloper? Select up to 3:
#   36. **WorkRemote**: How often do you work remotely?
#   37. **WorkLoc**: Where would you prefer to work?
#   38. ImpSyn: For the specific work you do, and the years of experience you have, how do you rate your own level of competence?
#   39. **CodeRev**: Do you review code as part of your work?
#   40. **CodeRevHrs**: On average, how many hours per week do you spend on code review?
#   41. **UnitTests**: Does your company regularly employ unit tests in the development of their products?
#   42. **PurchaseHow**: How does your company make decisions about purchasing new technology(cloud, AI, IoT, databases)?
#   43. PurchaseWhat: What level of influence do you, personally, have over new technology purchases at your organization?
#   44. **LanguageWorkedWith**: Which of the following programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)
#   45. **LanguageDesireNextYear**: Which of the following programming, scripting, and markup languages have you
# done extensive development work in over the past year, and which do you want
# to work in over the next year? (If you both worked with the language and want to
# continue to do so, please check both boxes in that row.)
#   46. **DatabaseWorkedWith**: Which of the following database environments have you done extensive
# development work in over the past year, and which do you want to work in over
# the next year? (If you both worked with the database and want to continue to do
# so, please check both boxes in that row.)
#
#   47. **DatabaseDesireNextYear**: Which of the following database environments have you done extensive
# development work in over the past year, and which do you want to work in over
# the next year? (If you both worked with the database and want to continue to do
# so, please check both boxes in that row.)
#   48. **PlatformWorkedWith**: Which of the following platforms have you done extensive development work
# for over the past year? (If you both developed for the platform and want to
# continue to do so, please check both boxes in that row.)
#
#   49. **PlatformDesireNextYear**:Which of the following platforms have you done extensive development work
# for over the past year? (If you both developed for the platform and want to
# continue to do so, please check both boxes in that row.)
#   50. **WebFrameWorkedWith**: Which of the following web frameworks have you done extensive development
# work in over the past year, and which do you want to work in over the next year?
# (If you both worked with the framework and want to continue to do so, please
# check both boxes in that row.)
#
#   51. **WebFrameDesireNextYear**: Which of the following web frameworks have you done extensive development
# work in over the past year, and which do you want to work in over the next year?
# (If you both worked with the framework and want to continue to do so, please
# check both boxes in that row.)
#   52. **MiscTechWorkedWith**: Which of the following other frameworks, libraries, and tools have you done
# extensive development work in over the past year, and which do you want to
# work in over the next year? (If you both worked with the technology and want to
# continue to do so, please check both boxes in that row.)
#   53. **MiscTechDesireNextYear**: Which of the following other frameworks, libraries, and tools have you done
# extensive development work in over the past year, and which do you want to
# work in over the next year? (If you both worked with the technology and want to
# continue to do so, please check both boxes in that row.)
#
#   54. **DevEnviron**: Which development environment(s) do you use regularly? Please check all that
# apply.
#   55. **OpSys**: What is the primary operating system in which you work?
#
#   56. Containers: How do you use containers (Docker, Open Container Initiative (OCI), etc.)?
#   57. BlockchainOrg: How is your organization thinking about or implementing blockchain
# technology?
#   58. BlockchainIs: Blockchain / cryptocurrency technology is primarily:
#   59. **BetterLife**: Do you think people born today will have a better life than their parents?
#   60. ITperson: Are you the “IT support person” for your family?
#   61. OffOn: Have you tried turning it off and on again?
#
#   62. **SocialMedia**: What social media site do you use the most?
#
#   63. Extraversion: Do you prefer online chat or IRL conversations?
#   64. ScreenName: What do you call it?
#
#   65. **SOVisit1st**: To the best of your memory, when did you first visit Stack Overflow?
#   66. **SOVisitFreq**: How frequently would you say you visit Stack Overflow?
#   67. **SOVisitTo**: I visit Stack Overflow to… (check all that apply)
#   68. **SOFindAnswer**: On average, how many times a week do you find (and use) an answer on Stack
# Overflow?
#   69. **SOTimeSaved**: Think back to the last time you solved a coding problem using Stack Overflow,
# as well as the last time you solved a problem using a different resource. Which
# was faster?
#   70. SOHowMuchTime: About how much time did you save? If you’re not sure, please use your best
# estimate
#   71. **SOAccount**: Do you have a Stack Overflow account?
#   72. SOPartFreq: How frequently would you say you participate in Q&A on Stack Overflow? By
# participate we mean ask, answer, vote for, or comment on questions.
#   73. SOJobs: Have you ever used or visited Stack Overflow Jobs?
#   74. EntTeams: Have you ever used Stack Overflow for Enterprise or Stack Overflow for
# Teams?
#   75. SOComm: Do you consider yourself a member of the Stack Overflow community?
#
#   76. WelcomeChange: Compared to last year, how welcome do you feel on Stack Overflow?
#   77. SONewContent: Would you like to see any of the following on Stack Overflow? Check all that
# apply.
#   78. **Age**: What is your age (in years)? If you prefer not to answer, you may leave this
# question blank.
#   79. **Gender**: Gender Which of the following do you currently identify as? Please select all that apply.
# If you prefer not to answer, you may leave this question blank.
#
#   80. **Trans**: Do you identify as transgender?
#   81. Sexuality: Which of the following do you currently identify as? Please select all that apply.
# If you prefer not to answer, you may leave this question blank
#   82. **Ethnicity**: Which of the following do you identify as? Please check all that apply. If you
# prefer not to answer, you may leave this question blank
#   83. **Dependents**: Do you have any dependents (e.g., children, elders, or others) that you care for?
#   84. SurveyLength: How do you feel about the length of the survey this year?
#   85. **SurveyEase**: How easy or difficult was this survey to complete?

# %% [markdown]
# *   As we can see, there are many columns that I think will not help me in the analysis (in my point of view), so I have put in bold the names of the columns that I will use to analyze this survey.

# %% [markdown]
# *   **Question(s) for Analysis**
#         1. How many primarily and non-primarily developers applied to the survey
#         2. How many people they taking coding as a hobby
#         3. Do people contribute to open-source
#         4. How do people feel about the quality of open-source software
#         5. who are the most kind of employees involved in the survey(full-time or part-time employees)?
#         6. What are the most participating countries in the survey?
#         7. What are the kinds of education levels that participated in the survey?
#         8. Did any students participate in the survey?
#         9. What are the main or most important fields of study?
#         10. What are the types of developers that participated in the survey?
#         11. Are the employees satisfied in their current jobs and in their career
#         12. What are the most common recent questions that were asked in job interviews?
#         13. Have you ever been asked to solve FizzBuzz in an interview?
#         14. what are the 3 MOST important factors for the employee when deciding between two job offers?
#         15. What is the most currency used day-to-day
#         16. Do many companies regularly employ unit tests in the development of their products?
#         17. how are employees are being paid (Yearly/Monthly/Weekly)
#         18. What is the Most Languages Worked with
#         19. What is the Most Database Worked with
#         20. What is the Most Web-frame Worked with
#         21. What is the Most Platform worked with
#         22. What is the Most Languages Desired Next Year
#         23. What is the Most Database Desired Next Year
#         24. What is the Most Web-frame Desired Next Year
#         25. What is the Most Platform Desired Next Year
#         26. What is the most operating system used
#         27. What are the most IDEs used
#         28. What social media sites use the most?
#         29. Who are the most participated in the survey, males or females?
#         30. How many people that participated in the survey have a Stack Overflow account?
#         31. What is the common use of containers?
#         32. What does people prefer online chatting or IRL conversations?
#         33. what is the average work hours
#         34. Is remote work common?
#         35. what is the most common work locations
#         36. what is the most common work challenges
#         37. Does code review became a part of work
#         38. what is the average hours per week spent on code review?
#         39. what is the average visits to stack overflow
#         40. Why people use Stack Overflow

# %% [markdown]
# # Importing Data And Librarires

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
import seaborn as sns
from google.colab import drive
# %matplotlib inline
from wordcloud import WordCloud

# %%
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Stack Overflow Survey Analysis/m1_survey_data.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
#  # Exploring Data

# %%
df.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %%
df.shape
# Out:
# (11552, 85)

# %%
df.shape[0] # Number of row
# Out:
# 11552

# %%
df.shape[1] # Number of columns
# Out:
# 85

# %%
df.dtypes
# Out:
# Respondent       int64
# MainBranch      object
# Hobbyist        object
# OpenSourcer     object
# OpenSource      object
#                  ...
# Sexuality       object
# Ethnicity       object
# Dependents      object
# SurveyLength    object
# SurveyEase      object
# Length: 85, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11552 entries, 0 to 11551
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              11552 non-null  int64
#  1   MainBranch              11552 non-null  object
#  2   Hobbyist                11552 non-null  object
#  3   OpenSourcer             11552 non-null  object
#  4   OpenSource              11471 non-null  object
#  5   Employment              11552 non-null  object
#  6   Country                 11552 non-null  object
#  7   Student                 11499 non-null  object
#  8   EdLevel                 11436 non-null  object
#  9   UndergradMajor          10812 non-null  object
#  10  EduOther                11388 non-null  object
#  11  OrgSize                 11454 non-null  object
#  12  DevType                 11485 non-null  object
#  13  YearsCode               11543 non-null  object
# ...

# %%
df.drop(columns=['Respondent','EduOther','OrgSize','YearsCode','Age1stCode','YearsCodePro','MgrIdiot','MgrMoney','MgrWant','JobSeek',
'LastHireDate','ResumeUpdate','CurrencySymbol','ImpSyn','PurchaseWhat','Containers','BlockchainOrg','BlockchainIs','ITperson','OffOn','Extraversion','ScreenName','SOHowMuchTime',
'SOPartFreq','SOJobs','EntTeams','SOComm','WelcomeChange','SONewContent','Sexuality','Sexuality','Ethnicity','Trans'],inplace=True)

# %%
df.shape
# Out:
# (11552, 53)

# %%
df.shape[1] # Number of columns
# Out:
# 53

# %%
df.dtypes
# Out:
# MainBranch                 object
# Hobbyist                   object
# OpenSourcer                object
# OpenSource                 object
# Employment                 object
# Country                    object
# Student                    object
# EdLevel                    object
# UndergradMajor             object
# DevType                    object
# CareerSat                  object
# JobSat                     object
# LastInt                    object
# FizzBuzz                   object
# JobFactors                 object
# CurrencyDesc               object
# CompTotal                 float64
# CompFreq                   object
# ConvertedComp             float64
# WorkWeekHrs               float64
# WorkPlan                   object
# WorkChallenge              object
# WorkRemote                 object
# WorkLoc                    object
# CodeRev                    object
# CodeRevHrs                float64
# UnitTests                  object
# ...

# %%
df.nunique()
# Out:
# MainBranch                   2
# Hobbyist                     2
# OpenSourcer                  4
# OpenSource                   3
# Employment                   2
# Country                    135
# Student                      3
# EdLevel                      9
# UndergradMajor              12
# DevType                   2756
# CareerSat                    5
# JobSat                       5
# LastInt                     63
# FizzBuzz                     2
# JobFactors                 157
# CurrencyDesc               102
# CompTotal                 1509
# CompFreq                     3
# ConvertedComp             3515
# WorkWeekHrs                113
# WorkPlan                     3
# WorkChallenge              129
# WorkRemote                   7
# WorkLoc                      3
# CodeRev                      3
# CodeRevHrs                  50
# UnitTests                    4
# PurchaseHow                  4
# LanguageWorkedWith        4534
# LanguageDesireNextYear    6052
# ...

# %%
df.isnull().sum()
# Out:
# MainBranch                   0
# Hobbyist                     0
# OpenSourcer                  0
# OpenSource                  81
# Employment                   0
# Country                      0
# Student                     53
# EdLevel                    116
# UndergradMajor             740
# DevType                     67
# CareerSat                    0
# JobSat                       1
# LastInt                    423
# FizzBuzz                    37
# JobFactors                   3
# CurrencyDesc                 0
# CompTotal                  815
# CompFreq                   206
# ConvertedComp              822
# WorkWeekHrs                125
# WorkPlan                   123
# WorkChallenge              168
# WorkRemote                   8
# WorkLoc                     32
# CodeRev                      1
# CodeRevHrs                2469
# UnitTests                   29
# PurchaseHow                198
# LanguageWorkedWith          11
# LanguageDesireNextYear     137
# ...

# %% [markdown]
# # Data Wrangling

# %%
df.query("Age>90")
# df[df['Age']>90]
# Out:
#                           MainBranch Hobbyist              OpenSourcer  \
# 9352  I am a developer by profession      Yes  Less than once per year
#
#                                              OpenSource          Employment  \
# 9352  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#             Country Student                                   EdLevel  \
# 9352  United States      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                          UndergradMajor  \
# 9352  Computer science, computer engineering, or sof...
#
#                     DevType  ...            SOVisitFreq  \
# 9352  Developer, full-stack  ...  Daily or almost daily
#
#                                               SOVisitTo        SOFindAnswer  \
# 9352  Find answers to specific questions;Learn how t...  3-5 times per week
#
#                              SOTimeSaved SOAccount   Age  Gender Dependents  \
# ...

# %%
df.drop(9352, inplace=True)

# %%
print('There are',len(df)-len(df.drop_duplicates()), 'duplicate rows.')
print('There are', df.duplicated().sum(), 'duplicate rows.')
# Out:
# There are 154 duplicate rows.
# There are 154 duplicate rows.

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (11397, 53)

# %%
print("There are", df['WorkLoc'].isnull().sum(), "missing values in the column 'WorkLoc'")
print("There are", df['EdLevel'].isnull().sum(), "missing values in the column 'EdLevel'")
print("There are", df['Country'].isnull().sum(), "missing values in the column 'Country'")
# Out:
# There are 32 missing values in the column 'WorkLoc'
# There are 112 missing values in the column 'EdLevel'
# There are 0 missing values in the column 'Country'

# %%
print('There are', df['WorkLoc'].nunique(), 'unique Work Locations in the survey:')
# Out:
# There are 3 unique Work Locations in the survey:

# %%
print('WorkLoc                                    value count')
print('-------                                    -----------')
df['WorkLoc'].value_counts()
# Out:
# WorkLoc                                    value count
# -------                                    -----------
# Office                                            6806
# Home                                              3588
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %%
df['WorkLoc'].mode() # If there is more two value most frequent it will return both of them
# Out:
# 0    Office
# Name: WorkLoc, dtype: object

# %%
df['UndergradMajor'].value_counts()
# Out:
# Computer science, computer engineering, or software engineering          6952
# Information systems, information technology, or system administration     794
# Another engineering discipline (ex. civil, electrical, mechanical)        759
# Web development or web design                                             410
# A natural science (ex. biology, chemistry, physics)                       403
# Mathematics or statistics                                                 372
# A business discipline (ex. accounting, finance, marketing)                244
# A social science (ex. anthropology, psychology, political science)        210
# A humanities discipline (ex. literature, history, philosophy)             207
# Fine arts or performing arts (ex. graphic design, music, studio art)      161
# I never declared a major                                                  124
# A health science (ex. nursing, pharmacy, radiology)                        24
# Name: UndergradMajor, dtype: int64

# %%
# Get top 10 most frequent names
df['Country'].value_counts()[:10]
# Out:
# United States     3126
# India              897
# United Kingdom     821
# Germany            708
# Canada             432
# France             339
# Brazil             325
# Australia          285
# Netherlands        254
# Spain              251
# Name: Country, dtype: int64

# %%
df['WorkLoc'].isnull().sum()
# Out:
# 32

# %%
df['WorkLoc'].replace(np.nan, 'Office', inplace=True)

# %%
df['WorkLoc'].isnull().sum()
# Out:
# 0

# %%
df['CompFreq'].value_counts()
# Out:
# Yearly     6072
# Monthly    4788
# Weekly      331
# Name: CompFreq, dtype: int64

# %%
df['CompTotal']
# Out:
# 0         61000.0
# 1        138000.0
# 2         90000.0
# 3         29000.0
# 4         90000.0
#            ...
# 11547    130000.0
# 11548     74400.0
# 11549    105000.0
# 11550     80000.0
# 11551         NaN
# Name: CompTotal, Length: 11397, dtype: float64

# %%
df.loc[df['CompFreq'] == 'Yearly', 'NormalizedAnnualCompensation']  = 1  * df['CompTotal'] # loc[row , column ]
df.loc[df['CompFreq'] == 'Monthly', 'NormalizedAnnualCompensation'] = 12 * df['CompTotal']
df.loc[df['CompFreq'] == 'Weekly', 'NormalizedAnnualCompensation']  = 52 * df['CompTotal']

# %%
df.isnull().sum()
# Out:
# MainBranch                         0
# Hobbyist                           0
# OpenSourcer                        0
# OpenSource                        81
# Employment                         0
# Country                            0
# Student                           51
# EdLevel                          112
# UndergradMajor                   737
# DevType                           65
# CareerSat                          0
# JobSat                             1
# LastInt                          413
# FizzBuzz                          37
# JobFactors                         3
# CurrencyDesc                       0
# CompTotal                        809
# CompFreq                         206
# ConvertedComp                    816
# WorkWeekHrs                      122
# WorkPlan                         121
# WorkChallenge                    164
# WorkRemote                         8
# WorkLoc                            0
# CodeRev                            1
# ...

# %%
# Function to fill NaN values with random non-NaN values from the same column
def fill_nan_with_random_values(df):
    for col in df.columns:
        nan_indices = df[df[col].isnull()].index  # Get indices of NaN values in the column
        non_nan_values = df[col].dropna().values  # Get non-NaN values from the column
        random_values = np.random.choice(non_nan_values, size=len(nan_indices))  # Choose random non-NaN values
        df.loc[nan_indices, col] = random_values  # Fill NaN values with random non-NaN values

# %%
fill_nan_with_random_values(df)

# %%
df.isnull().sum()
# Out:
# MainBranch                      0
# Hobbyist                        0
# OpenSourcer                     0
# OpenSource                      0
# Employment                      0
# Country                         0
# Student                         0
# EdLevel                         0
# UndergradMajor                  0
# DevType                         0
# CareerSat                       0
# JobSat                          0
# LastInt                         0
# FizzBuzz                        0
# JobFactors                      0
# CurrencyDesc                    0
# CompTotal                       0
# CompFreq                        0
# ConvertedComp                   0
# WorkWeekHrs                     0
# WorkPlan                        0
# WorkChallenge                   0
# WorkRemote                      0
# WorkLoc                         0
# CodeRev                         0
# CodeRevHrs                      0
# UnitTests                       0
# ...

# %%
df.shape
# Out:
# (11397, 54)

# %% [markdown]
# # Exploratory Data Analysis

# %%
df['Gender'].value_counts()
# Out:
# Man                                                            10545
# Woman                                                            737
# Non-binary, genderqueer, or gender non-conforming                 63
# Man;Non-binary, genderqueer, or gender non-conforming             27
# Woman;Non-binary, genderqueer, or gender non-conforming           14
# Woman;Man                                                          9
# Woman;Man;Non-binary, genderqueer, or gender non-conforming        2
# Name: Gender, dtype: int64

# %%
df['Age'].median()
# Out:
# 29.0

# %%
df[df['Gender'].eq('Woman')]['ConvertedComp'].median()
# Out:
# 58024.0

# %%
df['Age'].describe()
# Out:
# count    11397.000000
# mean        30.759524
# std          7.371159
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         72.000000
# Name: Age, dtype: float64

# %%
df.select_dtypes(include='float64').columns
# Out:
# Index(['CompTotal', 'ConvertedComp', 'WorkWeekHrs', 'CodeRevHrs', 'Age',
#        'NormalizedAnnualCompensation'],
#       dtype='object')

# %%
sns.boxplot(data=df,x='Age')
plt.show()

# %%
sns.boxplot(x=df["ConvertedComp"])
plt.show()

# %%
Q1 = df['ConvertedComp'].quantile(0.25)
Q3 = df['ConvertedComp'].quantile(0.75)
IQR = Q3 - Q1
print('The middle quartiles for ConvertedComp range from',Q1, 'to',Q3,'. The interquartile range is',IQR)
# It's an outlier if it is less than: Q1 - 1.5 * IQR. or if it is greater than: Q3 + 1.5 * IQR
print('Number of Outliers below:',df['ConvertedComp'].lt(Q1 - 1.5*IQR).sum())
print('Number of Outliers above:',df['ConvertedComp'].gt(Q3 + 1.5*IQR).sum())
# Out:
# The middle quartiles for ConvertedComp range from 26628.0 to 99240.0 . The interquartile range is 72612.0
# Number of Outliers below: 0
# Number of Outliers above: 941

# %%
min_val = df['ConvertedComp'].min()
max_val = df['ConvertedComp'].max()
print('The min/max for ConvertedComp are',min_val, 'and', max_val)
# Out:
# The min/max for ConvertedComp are 0.0 and 2000000.0

# %%
print('Median with outliers:',df['ConvertedComp'].median())
print('Median with outliers removed:',df[df['ConvertedComp'].le(Q3 + 1.5*IQR)]['ConvertedComp'].median())
print('Mean with outliers removed:',df[df['ConvertedComp'].le(Q3 + 1.5*IQR)]['ConvertedComp'].mean())
# Out:
# Median with outliers: 57744.0
# Median with outliers removed: 52704.0
# Mean with outliers removed: 59753.46537872992

# %%
# Remove Outliers
print(df.shape)
df = df[df['ConvertedComp'].le(Q3 + 1.5*IQR)]
df= df[df['ConvertedComp'].ge(Q1 - 1.5*IQR)]
print('total number of rows in new dataset:',df.shape[0])
# Out:
# (11397, 54)
# total number of rows in new dataset: 10456

# %%
df.corr()['Age']
# Out:
# <ipython-input-410-440c5838b7f8>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Age']
# CompTotal                       0.004951
# ConvertedComp                   0.359301
# WorkWeekHrs                     0.036861
# CodeRevHrs                     -0.013201
# Age                             1.000000
# NormalizedAnnualCompensation   -0.013675
# Name: Age, dtype: float64

# %%
sns.boxplot(x=df["ConvertedComp"])
plt.show()

# %% [markdown]
# # Questions for analysis

# %% [markdown]
# ## Question 1

# %% [markdown]
# **How many primarily and non-primarily developers applied to the survey**

# %%
df['MainBranch'].replace("I am a developer by profession","Primarily Developers",inplace=True)
df['MainBranch'].replace("I am not primarily a developer, but I write code sometimes as part of my work","Non-Primarily Developers",inplace=True)

# %%
df.groupby('MainBranch').size().plot(kind='bar')
plt.title("Numbers of primarily and non-primarily developers applied to the survey")
plt.ylabel("Counts")
plt.xticks(rotation="horizontal")
plt.show()

# %% [markdown]
# ## Question 2

# %% [markdown]
# **How many people they taking coding as a hobby**

# %%
df['Hobbyist'].value_counts().plot.pie(autopct='%1.1f%%',wedgeprops = {"edgecolor":'black','linewidth': 2},ylabel='Count',title='Number of people they taking coding as a hobby')
plt.show()

# %% [markdown]
# ## Question 3

# %% [markdown]
# **Do people contribute to open-source**

# %%
plt.pie(df['OpenSourcer'].value_counts(), explode = (0.2, 0.2,0.2,0.2) ,labels = df['OpenSourcer'].unique(),
        autopct = '%1.1f%%',shadow = True,
        startangle = 90,
        wedgeprops = {"edgecolor":"black",
                    'linewidth': 4})
plt.title('Do people contribute to open-source')
plt.show()

# %% [markdown]
# ## Question 4

# %% [markdown]
# **How do people feel about the quality of open-source software**

# %%
df['OpenSource'].value_counts()
df['OpenSource'].replace('The quality of OSS and closed source software is about the same','The Quality of OSS and CSS are the same',inplace=True)
df['OpenSource'].replace('OSS is, on average, of HIGHER quality than proprietary / closed source software','On Average OSS has better quality',inplace=True)
df['OpenSource'].replace('OSS is, on average, of LOWER quality than proprietary / closed source software','On Average CSS has better quality',inplace=True)

# %%
df.groupby('OpenSource').size().plot(kind='barh')
plt.ylabel("Counts")
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# ## Question 5

# %% [markdown]
# **who are the most kind of employees involved in the survey(full-time or part-time employees)?**

# %%
df['Employment'].value_counts()
df.groupby('Employment').size().plot(kind='bar')
plt.ylabel("Counts")
plt.xticks(rotation="horizontal")
plt.show()

# %% [markdown]
# ## Question 6

# %% [markdown]
# **What are the most participating countries in the survey?**

# %%
df["Country"].value_counts()[0:10]
df["Country"].value_counts()[0:10].plot(kind='bar')
plt.title('Most participating countries in the survey')
plt.show()

# %% [markdown]
# ## Question 7

# %% [markdown]
# **What are the kinds of education levels that participated in the survey?**

# %%
df["EdLevel"].value_counts().plot(kind='barh')
plt.title('Education Qualification Prcentage in the dataset')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Question 8

# %% [markdown]
# **Did any students participate in the survey?**

# %%
df["Student"].value_counts().plot(kind='barh')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Question 9

# %% [markdown]
# **What are the main or most important fields of study?**

# %%
text = df['UndergradMajor'].values
wordcloud = WordCloud(background_color='white',width = 1000, height = 500).generate(str(text))
plt.imshow(wordcloud)
plt.axis("off")
plt.title('Most important fields of study')
plt.show()

# %% [markdown]
# ## Question 10

# %% [markdown]
# **What are the types of developers that participated in the survey?**

# %%
text = df['DevType'].values
wordcloud = WordCloud(background_color='white',width = 1000, height = 500).generate(str(text))
plt.imshow(wordcloud)
plt.axis("off")
plt.title('Most shown Job title')
plt.show()

# %% [markdown]
# ## Question 11

# %% [markdown]
# **Are the employees satisfied in their current jobs and in their career**

# %%
plt.figure(figsize=(16,8))
sns.countplot(x=df['JobSat'],hue=df.CareerSat)
plt.xticks(rotation='vertical')
plt.title('The relation between the Career and jop ')
plt.show()

# %% [markdown]
# ## Question 12

# %% [markdown]
# **What are the most common recent questions that were asked in job interviews?**

# %%
df["LastInt"].value_counts()[0:5].plot(kind='barh')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Question 13

# %% [markdown]
# **Have you ever been asked to solve FizzBuzz in an interview**

# %%
df['FizzBuzz'].value_counts().plot.pie(autopct='%1.1f%%',wedgeprops = {"edgecolor":'black','linewidth': 2},ylabel='',title='Have you ever been asked to solve FizzBuzz in an interview')
plt.show()

# %% [markdown]
# ## Question 14

# %% [markdown]
# **what are the 3 MOST important factors for the employee when deciding between two job offers?**

# %%
text = df['JobFactors'].values
wordcloud = WordCloud(background_color='white',width = 1000, height = 500).generate(str(text))
plt.imshow(wordcloud)
plt.axis("off")
plt.title('Most important factors')
plt.show()

# %% [markdown]
# ## Question 15

# %% [markdown]
# **What is the most currency used day-to-day**

# %%
df["CurrencyDesc"].value_counts()[0:5].plot(kind='barh')
plt.show()

# %% [markdown]
# ## Question 16

# %% [markdown]
# **Do many companies regularly employ unit tests in the development of their products?**

# %%
plt.pie(df['UnitTests'].value_counts(), explode = (0.02, 0.02,0.02,0.02) ,labels = df['UnitTests'].unique(),
        autopct = '%1.1f%%',shadow = True,
        startangle = 90,
        wedgeprops = {"edgecolor":"black",
                    'linewidth': 0.5})
plt.show()

# %% [markdown]
# ## Question 17

# %% [markdown]
# **how are employees are being paid (Yearly/Monthly/Weekly)**

# %%
plt.pie(df['CompFreq'].value_counts(), explode = (0.02, 0.02,0.02) ,labels = df['CompFreq'].unique(),
        autopct = '%1.1f%%',
        startangle = 90,
        wedgeprops = {"edgecolor":"black",
                    'linewidth': 0.1})
plt.show()

# %% [markdown]
# # Analysis Using SQL

# %%
conn = sqlite3.connect("/content/drive/MyDrive/Colab Notebooks/Stack Overflow Survey Analysis/m4_survey_data.sqlite") # open a database connection

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name
FROM sqlite_master
WHERE type = 'table' and name in ('LanguageWorkedWith','LanguageDesireNextYear','DatabaseWorkedWith','DatabaseDesireNextYear','PlatformWorkedWith')
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
dff=pd.read_sql_query(QUERY,conn)
dff
# Out:
#                Table_Name
# 0      LanguageWorkedWith
# 1  LanguageDesireNextYear
# 2      DatabaseWorkedWith
# 3  DatabaseDesireNextYear
# 4      PlatformWorkedWith

# %%
QUERY = """
SELECT sql
FROM sqlite_schema
"""
# sqlite_master is a system table in SQLite that stores metadata about the database schema.
# This query fetches the SQL statements used to create **all tables** in the database.
a = conn.execute(QUERY)
# fetch all records
# print(a.fetchall())
dff = pd.read_sql_query(QUERY,conn)
print(dff.iat[23,0]) #Get value at specified row/column pair
dff
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
# ...

# %% [markdown]
# ## Question 18

# %% [markdown]
# **What is the Most Languages Worked with**

# %%
# QUERY="""
# Select sql
# FROM sqlite_schema
# WHERE name = 'LanguageWorkedWith'
# """
# dff = pd.read_sql_query(QUERY,conn) # Table that i will work on
# print(dff.iat[0,0]) #Get value at specified row/column pair
QUERY = """
SELECT LanguageWorkedWith, count(LanguageWorkedWith) as Count
FROM LanguageWorkedWith
GROUP BY LanguageWorkedWith
"""
dff = pd.read_sql_query(QUERY,conn)
dff.sort_values('Count', ascending=False,inplace=True)
dff = dff.head(10) # get top five
dff.plot.bar(x='LanguageWorkedWith')
plt.xlabel('LanguageWorkedWith')
plt.ylabel('Respondent')
plt.show()

# %%
# QUERY="""
# Select sql
# FROM sqlite_schema
# WHERE name = 'DatabaseWorkedWith'
# """
# df = pd.read_sql_query(QUERY,conn)
# print(df.iat[0,0]) #Get value at specified row/column pair
QUERY = """
SELECT DatabaseWorkedWith, count(DatabaseWorkedWith) as Count
FROM DatabaseWorkedWith
GROUP BY DatabaseWorkedWith
"""
dff = pd.read_sql_query(QUERY,conn)
dff.sort_values('Count', ascending=False,inplace=True)
dff = dff.head(10) # get top five
dff.plot.bar(x='DatabaseWorkedWith')
plt.xlabel('DatabaseWorkedWith')
plt.ylabel('Respondent')
plt.show()

# %% [markdown]
# ## Question 19

# %% [markdown]
# **What is the Most Database Worked with**

# %%
# QUERY="""
# Select sql
# FROM sqlite_schema
# WHERE name = 'DatabaseDesireNextYear'
# """
# df = pd.read_sql_query(QUERY,conn)
# print(df.iat[0,0]) #Get value at specified row/column pair
QUERY = """
SELECT DatabaseDesireNextYear, count(DatabaseDesireNextYear) as Count
FROM DatabaseDesireNextYear
GROUP BY DatabaseDesireNextYear
"""
dff = pd.read_sql_query(QUERY,conn)
dff.sort_values('Count', ascending=False,inplace=True)
dff = dff.head(5) # get top five
dff['Count'].plot(kind='pie',
                            figsize=(5, 6),
                            autopct='%1.1f%%', # add in percentages number reounded by one
                            labels=dff['DatabaseDesireNextYear'])
plt.title('Top 5 Database Worked with')
plt.show()

# %% [markdown]
# ## Question 20

# %% [markdown]
# **What is the Most Web-frame Worked with**

# %%
# QUERY="""
# Select sql
# FROM sqlite_schema
# WHERE name = 'LanguageDesireNextYear'
# """
# df = pd.read_sql_query(QUERY,conn)
# print(df.iat[0,0]) #Get value at specified row/column pair
QUERY = """
SELECT WebFrameWorkedWith, count(WebFrameWorkedWith) as Count
FROM WebFrameWorkedWith
GROUP BY WebFrameWorkedWith
"""

dff = pd.read_sql_query(QUERY,conn)
dff.sort_values('Count', ascending=False,inplace=True)
dff = dff.head(5) # get top five
dff['Count'].plot(kind='pie',
                            figsize=(5, 6),
                            autopct='%1.1f%%', # add in percentages number reounded by one
                            labels=dff['WebFrameWorkedWith'])

plt.title('Top 5 Web-frame Worked with')
plt.show()

# %% [markdown]
# ## Question 21

# %% [markdown]
# **What is the Most Platform worked with**

# %%
Query="""
select PlatformWorkedWith ,count(PlatformWorkedWith) as Count
from PlatformWorkedWith
GROUP by PlatformWorkedWith
"""
dff = pd.read_sql_query(Query,conn)
dff.sort_values('Count', ascending=False,inplace=True)
dff = dff.head(5) # get top five
dff
dff['Count'].plot(kind='pie',
                            figsize=(5, 6),
                            autopct='%1.1f%%', # add in percentages number reounded by one
                           labels=dff['PlatformWorkedWith'])

plt.title('Top 5 Platform Worked With ')
plt.show()

# %% [markdown]
# ## Question 22

# %% [markdown]
# **What is the Most Languages Desired Next Year**

# %%
Query="""
select LanguageDesireNextYear ,count(LanguageDesireNextYear) as Count
from LanguageDesireNextYear
group by LanguageDesireNextYear
"""
dff=pd.read_sql_query(Query,conn)
dff.sort_values('Count', ascending=False,inplace=True)
dff=dff.head(5)
plt.bar(dff['LanguageDesireNextYear'],dff['Count'])
plt.title("Top 5 Language Desire Next Year")
plt.show()

# %% [markdown]
# ## Question 23

# %% [markdown]
# **What is the Most Database Desired Next Year**

# %%
Query="""
select DatabaseDesireNextYear ,count(DatabaseDesireNextYear) as Count
from DatabaseDesireNextYear
group by DatabaseDesireNextYear
"""
dff=pd.read_sql_query(Query,conn)
dff.sort_values('Count', ascending=False,inplace=True)
dff=dff.head(5)
plt.bar(dff['DatabaseDesireNextYear'],dff['Count'])
plt.title("Top 5 Database Desire Next Year")
plt.show()

# %% [markdown]
# ## Question 24

# %% [markdown]
# **What is the Most Web-frame Desired Next Year**

# %%
Query="""
select WebFrameDesireNextYear ,count(WebFrameDesireNextYear) as Count
from WebFrameDesireNextYear
group by WebFrameDesireNextYear
"""
dff=pd.read_sql_query(Query,conn)
dff.sort_values('Count', ascending=False,inplace=True)
dff=dff.head(5)
plt.barh(dff['WebFrameDesireNextYear'],dff['Count'])
plt.title("Top 5 WebFrame Desire Next Year")
plt.xticks(rotation="vertical")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Question 25

# %% [markdown]
# **What is the Most Platform Desired Next Year**

# %%
Query="""
select PlatformDesireNextYear ,count(PlatformDesireNextYear) as Count
from PlatformDesireNextYear
group by PlatformDesireNextYear
"""
dff=pd.read_sql_query(Query,conn)
dff.sort_values('Count', ascending=False,inplace=True)
dff=dff.head(5)
plt.barh(dff['PlatformDesireNextYear'],dff['Count'])
plt.title("Top 5 Platform Desire Next Year")
plt.xticks(rotation="vertical")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Question 26

# %% [markdown]
# **What is the most operating system used**

# %%
QUERY = """
SELECT OpSys, count(OpSys) as Count
FROM master
GROUP BY OpSys
"""
dff=pd.read_sql_query(QUERY,conn)
dff.sort_values('Count', ascending=False,inplace=True)
dff=dff.head(3)
plt.bar(dff['OpSys'],dff['Count'])
plt.title("Top 3 operating system used in work")
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# ## Question 27

# %% [markdown]
# **What are the most IDEs used**

# %%
text = df['DevEnviron'].values
wordcloud = WordCloud(background_color='white',width = 1000, height = 500).generate(str(text))
plt.imshow(wordcloud)
plt.axis("off")
plt.title('Most IDEs used')
plt.show()

# %% [markdown]
# ## Question 28

# %% [markdown]
# **What social media sites use the most?**

# %%
QUERY = """
SELECT SocialMedia, count(SocialMedia) as Count
FROM master
GROUP BY SocialMedia
"""

dff = pd.read_sql_query(QUERY,conn)
dff.sort_values('Count', ascending=False,inplace=True)
dff = dff.head(5) # get top five
dff['Count'].plot(kind='pie',
                            figsize=(5, 6),
                            autopct='%1.1f%%', # add in percentages number reounded by one
                            labels=dff['SocialMedia'],ylabel="")

plt.title('Top 5 social media sites used')
plt.show()

# %% [markdown]
# ## Question 29

# %% [markdown]
# **Who are the most participated in the survey, males or females?**

# %%
Query="""
select Gender ,count(Gender) as Count
from Gender
group by Gender
"""
dff = pd.read_sql_query(Query,conn)
dff.sort_values('Count', ascending=False,inplace=True)
dff=dff.head(2)
plt.bar(dff['Gender'],dff['Count'])
plt.xticks(rotation="horizontal")
plt.show()

# %% [markdown]
# ## Question 30

# %% [markdown]
# **How many people that participated in the survey have a Stack Overflow account?**

# %%
Query="""
select SOAccount ,count(SOAccount) as Count
from master
group by SOAccount
"""
dff = pd.read_sql_query(Query,conn)
dff.sort_values('Count', ascending=False,inplace=True)
dff=dff.head(2)
plt.bar(dff['SOAccount'],dff['Count'])
plt.xticks(rotation="horizontal")
plt.show()

# %% [markdown]
# ## Question 31

# %% [markdown]
# **What is the common use of containers?**

# %%
QUERY = """
SELECT Containers, count(Containers) as Count
FROM Containers
GROUP BY Containers
"""
dff=pd.read_sql_query(QUERY,conn)
dff.sort_values('Count', ascending=False,inplace=True)
plt.barh(dff['Containers'],dff['Count'])
plt.title("The common use of containers")
plt.xticks(rotation="vertical")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Question 32

# %% [markdown]
# **What does people prefer online chatting or IRL conversations?**

# %%
QUERY = """
SELECT Extraversion, count(Extraversion) as Count
FROM master
GROUP BY Extraversion
"""
dff=pd.read_sql_query(QUERY,conn)
dff.sort_values('Count', ascending=False,inplace=True)
dff=dff.head(3)
plt.barh(dff['Extraversion'],dff['Count'])
plt.xticks(rotation="horizontal")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Question 33

# %% [markdown]
# **what is the average work hours**

# %%
Avg_WorkWeekHrs=df.groupby('Country')['WorkWeekHrs'].mean().reset_index()
Avg_WorkWeekHrs=Avg_WorkWeekHrs.sort_values('WorkWeekHrs',ascending = False).head(5)
plt.barh(Avg_WorkWeekHrs['Country'],Avg_WorkWeekHrs['WorkWeekHrs'])
plt.xlabel("Average work hours")
plt.show()

# %% [markdown]
# ## Question 34

# %% [markdown]
# **Is remote work common?**

# %%
df['WorkRemote'].value_counts()
plt.pie(df['WorkRemote'].value_counts()[0:4], explode = (0.2, 0.2,0.2,0.2) ,labels = df['WorkRemote'].unique()[0:4],
        autopct = '%1.1f%%',shadow = True,
        startangle = 90,
        wedgeprops = {"edgecolor":"black",
                    'linewidth': 4})
plt.show()

# %% [markdown]
# ## Question 35

# %% [markdown]
# **what is the most common work locations**

# %%
Query="""
select WorkLoc ,count(WorkLoc) as Count
from master
group by WorkLoc
"""
dff = pd.read_sql_query(Query,conn)
dff.sort_values('Count', ascending=False,inplace=True)
dff=dff.head(3)
plt.barh(dff['WorkLoc'],dff['Count'])
plt.xticks(rotation="horizontal")
plt.show()

# %% [markdown]
# ## Question 36

# %% [markdown]
# **what is the most common work challenges**

# %%
Query="""
select WorkChallenge ,count(WorkChallenge) as Count
from WorkChallenge
group by WorkChallenge
"""
dff = pd.read_sql_query(Query,conn)
dff.sort_values('Count', ascending=False,inplace=True)
dff=dff.head(10)
plt.barh(dff['WorkChallenge'],dff['Count'])
plt.xticks(rotation="horizontal")
plt.title("Top 10 Work challenges ")
plt.show()

# %% [markdown]
# ## Question 37

# %% [markdown]
# **Does code review became a part of work**

# %%
Query="""
select CodeRev ,count(CodeRev) as Count
from master
group by CodeRev
"""
dff = pd.read_sql_query(Query,conn)
dff.sort_values('Count', ascending=False,inplace=True)
dff=dff.head(3)
plt.barh(dff['CodeRev'],dff['Count'])
plt.xticks(rotation="horizontal")
plt.show()

# %% [markdown]
# ## Question 38

# %% [markdown]
# **what is the average hours per week spent on code review?**

# %%
QUERY = """
SELECT LanguageWorkedWith.LanguageWorkedWith, master.CodeRevHrs
FROM LanguageWorkedWith
INNER JOIN master ON LanguageWorkedWith.Respondent = master.Respondent;
"""
dff = pd.read_sql_query(QUERY,conn)
Avg_WorkWeekHrs=dff.groupby("LanguageWorkedWith")['CodeRevHrs'].mean().reset_index()
Avg_WorkWeekHrs.sort_values('CodeRevHrs', ascending=False,inplace=True)
Avg_WorkWeekHrs=Avg_WorkWeekHrs.head(5)
plt.barh(Avg_WorkWeekHrs['LanguageWorkedWith'],Avg_WorkWeekHrs['CodeRevHrs'])
plt.title("Top Languages that taking coding review per week")
plt.show()

# %% [markdown]
# ## Question 39

# %% [markdown]
# **what is the average visits to stack overflow**

# %%
df['SOVisitFreq'].value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# ## Question 40

# %% [markdown]
# **Why people use Stack Overflow**

# %%
text = df['SOVisitTo'].values
wordcloud = WordCloud(background_color='white',width = 1000, height = 500).generate(str(text))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
QUERY = """
SELECT ConvertedComp, Age
FROM master
"""
dff = pd.read_sql_query(QUERY,conn)
dff = dff.groupby('Age', axis=0).median()
# step 2: plot data
dff[25:30].plot(kind='line', figsize=(10, 6))
plt.xlabel('Age') # add to x-label to the plot
plt.ylabel('$') # add y-label to the plot
plt.title('Median Compensation by Age (25:30)') # add title to the plot
plt.show()

# %%
conn.close()
